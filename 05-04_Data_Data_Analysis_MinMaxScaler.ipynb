# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Loading the data
df = pd.read_csv('winequality-red.csv', header = 0, delimiter=';')
headers = df.columns
data = df.values

# Using all features for PCA visualization
X = df.drop(['quality'],axis=1)
y = df.quality

# Standardize the data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Applying PCA 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Visualizing the data in the reduced-dimensional space
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.colorbar(label="Class")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('PCA Visualization')
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.show()

# %%
# Obtaining classes 5 & 6 for PCA visualization
df_5_6 = df.loc[df['quality'].isin([5,6])]
X = df_5_6.drop(['quality'],axis=1)
y = df_5_6.quality

# Standardize the data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Applying PCA 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Visualizing the data in the reduced-dimensional space
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.colorbar(label="Class")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('PCA Visualization Classes 5 & 6')
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.show()

# %%
# Obtaining classes 5 & 6 for PCA visualization
df_5_6 = df.loc[df['quality'].isin([5,6])]
X = df_5_6.drop(['quality','fixed acidity'],axis=1)
y = df_5_6.quality

# Standardize the data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Applying PCA 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Visualizing the data in the reduced-dimensional space
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.colorbar(label="Class")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('PCA Visualization Classes 5 & 6, dropped fixed acidity')
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.show()

# %%
# Obtaining classes 3, 4, 7, 8 PCA visualization
df_3_4_7_8 = df.loc[df['quality'].isin([3,4,7,8])]
X = df_3_4_7_8.drop(['quality'],axis=1)
y = df_3_4_7_8.quality

# Standardize the data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Applying PCA 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Visualizing the data in the reduced-dimensional space
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.colorbar(label="Class")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('PCA Visualization Classes 3, 4, 7, 8')
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.show()

# %%
# Obtaining classes 3 & 8 PCA visualization
df_3_8 = df.loc[df['quality'].isin([3,8])]
X = df_3_8.drop(['quality'],axis=1)
y = df_3_8.quality

# Standardize the data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Applying PCA 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Visualizing the data in the reduced-dimensional space
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.colorbar(label="Class")
plt.xlabel('First Principal Component')
plt.xlim([-1.1,1.1])
plt.ylim([-1.1,1.1])
plt.show()

# %%
# Adjusting figure size
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

# Creating histogram of data set
df.hist(ax=ax)
plt.show()

# Creating correlation heat map of data set
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt='.2f')
# Out:
# /var/folders/1t/vpp_nh5d6gs4r8shhb5ywk4c0000gn/T/ipykernel_58360/244895675.py:6: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax)
# <AxesSubplot:>

# %%
# Setting y back to the quality column of the whole data set
y = df.quality

# Obttaining unique values and counts from the quality column
unique_values, counts = np.unique(y, return_counts=True)

# Using unqiue values and counts for creating a pie chart
plt.pie(counts,shadow=True,autopct='%.1f%%')
plt.legend(unique_values)
plt.title('Pie chart of red wine quality')
plt.show()
